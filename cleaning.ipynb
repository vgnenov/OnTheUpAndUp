# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime as dt

# %%
csvpath = "Illinois_Mean_Salary.csv"
mean_salary = pd.read_csv(csvpath)
mean_salary.head(10)
# Out:
#      Year  Mean Hourly Wage  Annual Mean Wage  Median Hourly Wage  \
# 0  2019.0             43.32           90110.0               41.89
# 1  2018.0             42.17           87720.0               40.65
# 2  2017.0             41.74           86820.0               40.13
# 3  2016.0             41.03           85340.0               39.58
# 4  2015.0             39.68           82540.0               38.54
# 5  2014.0             38.30           79670.0               37.43
# 6  2013.0             37.63           78260.0               36.86
# 7  2012.0             37.26           77500.0               36.26
# 8  2011.0             36.63           76180.0               35.29
# 9  2010.0             36.12           75130.0               34.61
#
#    Median Weekly Earnings  Annual Median Wage  Unnamed: 6  Unnamed: 7  \
# 0                  1676.0             83780.0         NaN         NaN
# 1                  1626.0             81300.0         NaN         NaN
# ...

# %%
nan_value = float("NaN")
mean_salary.replace("", nan_value, inplace = False)
mean_salary.head(10)
# Out:
#      Year  Mean Hourly Wage  Annual Mean Wage  Median Hourly Wage  \
# 0  2019.0             43.32           90110.0               41.89
# 1  2018.0             42.17           87720.0               40.65
# 2  2017.0             41.74           86820.0               40.13
# 3  2016.0             41.03           85340.0               39.58
# 4  2015.0             39.68           82540.0               38.54
# 5  2014.0             38.30           79670.0               37.43
# 6  2013.0             37.63           78260.0               36.86
# 7  2012.0             37.26           77500.0               36.26
# 8  2011.0             36.63           76180.0               35.29
# 9  2010.0             36.12           75130.0               34.61
#
#    Median Weekly Earnings  Annual Median Wage  Unnamed: 6  Unnamed: 7  \
# 0                  1676.0             83780.0         NaN         NaN
# 1                  1626.0             81300.0         NaN         NaN
# ...

# %%
reduced_mean_salary = mean_salary [["Year", "Mean Hourly Wage", "Annual Mean Wage", "Median Hourly Wage", "Median Weekly Earnings", "Annual Median Wage"]]
reduced_mean_salary.head(10)
# Out:
#      Year  Mean Hourly Wage  Annual Mean Wage  Median Hourly Wage  \
# 0  2019.0             43.32           90110.0               41.89
# 1  2018.0             42.17           87720.0               40.65
# 2  2017.0             41.74           86820.0               40.13
# 3  2016.0             41.03           85340.0               39.58
# 4  2015.0             39.68           82540.0               38.54
# 5  2014.0             38.30           79670.0               37.43
# 6  2013.0             37.63           78260.0               36.86
# 7  2012.0             37.26           77500.0               36.26
# 8  2011.0             36.63           76180.0               35.29
# 9  2010.0             36.12           75130.0               34.61
#
#    Median Weekly Earnings  Annual Median Wage
# 0                  1676.0             83780.0
# 1                  1626.0             81300.0
# 2                  1605.0             80260.0
# 3                  1583.0             79160.0
# ...

# %%
reduced_mean_salary = reduced_mean_salary.dropna(how='any')
reduced_mean_salary.head(20)

# %%
reduced_mean_salary.to_csv("Cleaned_Illinois_Mean_Salary.csv", encoding="utf-8", index=False)

# %%
csvpath = "Industry_Gender_Pay_Gap.csv"
ind_gen_gap = pd.read_csv(csvpath)
ind_gen_gap.head(10)
# Out:
#    Year  Number of workers (Total) Median weekly earnings (Total)  \
# 0  2019                      629.0                          1,984
# 1  2018                      601.0                          1,877
# 2  2017                      594.0                          1,843
# 3  2016                      592.0                          1,738
# 4  2015                      636.0                          1,728
# 5  2014                      623.0                          1,730
# 6  2013                      570.0                          1,728
# 7  2012                      568.0                          1,672
# 8  2011                      530.0                          1,579
# 9  2010                      505.0                          1,600
#
#    Number of workers (Men) Median weekly earnings (Men)  \
# 0                    439.0                        2,019
# 1                    448.0                        1,920
# 2                    428.0                        1,897
# ...

# %%
nan_value = float("NaN")
ind_gen_gap.replace("", nan_value, inplace = False)
ind_gen_gap.head(10)
# Out:
#    Year  Number of workers (Total) Median weekly earnings (Total)  \
# 0  2019                      629.0                          1,984
# 1  2018                      601.0                          1,877
# 2  2017                      594.0                          1,843
# 3  2016                      592.0                          1,738
# 4  2015                      636.0                          1,728
# 5  2014                      623.0                          1,730
# 6  2013                      570.0                          1,728
# 7  2012                      568.0                          1,672
# 8  2011                      530.0                          1,579
# 9  2010                      505.0                          1,600
#
#    Number of workers (Men) Median weekly earnings (Men)  \
# 0                    439.0                        2,019
# 1                    448.0                        1,920
# 2                    428.0                        1,897
# ...

# %%
#reduced_mean_salary = mean_salary [["Year", "Mean Hourly Wage", "Annual Mean Wage", "Median Hourly Wage", "Median Weekly Earnings", "Annual Median Wage"]]
#reduced_mean_salary.head(10)

# %%
reduced_ind_gen_gap = ind_gen_gap.dropna(how='any')
reduced_ind_gen_gap.head(20)

reduced_ind_gen_gap.to_csv("Cleaned_Industry_Gender_Pay_Gap.csv", encoding="utf-8", index=False)
