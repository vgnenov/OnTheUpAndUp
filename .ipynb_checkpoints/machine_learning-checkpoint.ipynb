# %%
 # %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
nat_unemp_gen = pd.read_csv('National_Unemployment_by_Gender.csv')
nat_unemp_gen.head()
# Out:
#      Month  Total  Men, 20 years and over  Women, 20 years and over  \
# 0  10/1/00    3.9                     3.3                       3.3
# 1  11/1/00    3.9                     3.4                       3.4
# 2  12/1/00    3.9                     3.4                       3.3
# 3   1/1/01    4.2                     3.6                       3.6
# 4   2/1/01    4.2                     3.7                       3.7
#
#    16 to 19 years old  White  Black or African American  Asian  \
# 0                12.8    3.4                        7.3    NaN
# 1                13.0    3.5                        7.3    NaN
# 2                13.2    3.5                        7.4    NaN
# 3                13.8    3.6                        8.2    NaN
# 4                13.7    3.7                        7.7    NaN
#
#    Hispanic or Latino
# 0                 5.1
# 1                 6.0
# 2                 5.7
# 3                 5.8
# 4                 6.1

# %%
nat_unemp_gen.dropna()
# Out:
#        Month  Total  Men, 20 years and over  Women, 20 years and over  \
# 27    1/1/03    5.8                     5.6                       4.9
# 28    2/1/03    5.9                     5.5                       5.1
# 29    3/1/03    5.9                     5.4                       5.1
# 30    4/1/03    6.0                     5.7                       5.1
# 31    5/1/03    6.1                     5.8                       5.2
# ..       ...    ...                     ...                       ...
# 236   6/1/20   11.1                    10.2                      11.2
# 237   7/1/20   10.2                     9.4                      10.5
# 238   8/1/20    8.4                     8.0                       8.4
# 239   9/1/20    7.9                     7.4                       7.7
# 240  10/1/20    6.9                     6.7                       6.5
#
#      16 to 19 years old  White  Black or African American  Asian  \
# ...

# %%
X = nat_unemp_gen[["White", "Black or African American", "Asian", "Hispanic or Latino"]]
y = nat_unemp_gen["Month"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (241, 4) (241, 1)

# %%
#nat_unemp_gen = nat_unemp_gen.reset_index()
#nan_value = float("NaN")
#nat_unemp_gen.replace("", nan_value, inplace = False)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#np.where(x.values >= np.finfo(np.float64).max)
y_test = np.nan_to_num(y_test)
np.isnan(X)
np.where(np.isnan(X))
np.nan_to_num(X)
# Out:
# array([[ 3.4,  7.3,  0. ,  5.1],
#        [ 3.5,  7.3,  0. ,  6. ],
#        [ 3.5,  7.4,  0. ,  5.7],
#        [ 3.6,  8.2,  0. ,  5.8],
#        [ 3.7,  7.7,  0. ,  6.1],
#        [ 3.7,  8.3,  0. ,  6.2],
#        [ 3.9,  8. ,  0. ,  6.4],
#        [ 3.8,  7.9,  0. ,  6.3],
#        [ 4. ,  8.3,  0. ,  6.6],
#        [ 4. ,  8. ,  0. ,  6.2],
#        [ 4.3,  9.1,  0. ,  6.5],
#        [ 4.3,  8.9,  0. ,  6.7],
#        [ 4.7,  9.5,  0. ,  7.1],
#        [ 4.9,  9.8,  0. ,  7.3],
#        [ 5.1, 10.1,  0. ,  7.7],
#        [ 5.1, 10. ,  0. ,  7.8],
#        [ 5. ,  9.9,  0. ,  7. ],
#        [ 5. , 10.5,  0. ,  7.5],
#        [ 5.2, 10.7,  0. ,  8. ],
#        [ 5.1, 10.2,  0. ,  7.1],
#        [ 5.1, 10.5,  0. ,  7.4],
#        [ 5.2,  9.8,  0. ,  7.4],
#        [ 5.1,  9.8,  0. ,  7.5],
#        [ 5.1,  9.7,  0. ,  7.4],
#        [ 5.1,  9.8,  0. ,  7.9],
#        [ 5.1, 10.7,  0. ,  7.8],
#        [ 5.1, 11.3,  0. ,  7.9],
#        [ 5.2, 10.5,  5.5,  7.9],
# ...

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d7eca1cbd4e7> in <module>
# ----> 1 model.fit(X_train, y_train)
#       2 training_score = model.score(X_train, y_train)
#       3 testing_score = model.score(X_test, y_test)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# ...
